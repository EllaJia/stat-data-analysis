# %%
import pandas as pd
from pandas import DataFrame
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import seaborn as sns

# %%
# Part 1: Read in COVID-19 death data
path = r'C:\Users\ellen\Desktop\Data Analysis with Python\Project 2 - data\data\\'
df = pd.read_csv(path + 'Conditions_Contributing_to_COVID-19_Deaths__by_State_and_Age__Provisional_2020-2022.csv')
# Out:
# C:\Users\ellen\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (11,12) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 471960 entries, 0 to 471959
# Data columns (total 14 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Data As Of          471960 non-null  object
#  1   Start Date          471960 non-null  object
#  2   End Date            471960 non-null  object
#  3   Group               471960 non-null  object
#  4   Year                459540 non-null  object
#  5   Month               422280 non-null  float64
#  6   State               471960 non-null  object
#  7   Condition Group     471960 non-null  object
#  8   Condition           471960 non-null  object
#  9   ICD10_codes         471960 non-null  object
#  10  Age Group           471960 non-null  object
#  11  COVID-19 Deaths     338022 non-null  object
#  12  Number of Mentions  342287 non-null  object
#  13  Flag                133938 non-null  object
# dtypes: float64(1), object(13)
# memory usage: 50.4+ MB

# %%
df.head(10)
# Out:
#    Data As Of  Start Date    End Date     Group Year  Month          State  \
# 0  10/02/2022  01/01/2020  10/01/2022  By Total  NaN    NaN  United States
# 1  10/02/2022  01/01/2020  10/01/2022  By Total  NaN    NaN  United States
# 2  10/02/2022  01/01/2020  10/01/2022  By Total  NaN    NaN  United States
# 3  10/02/2022  01/01/2020  10/01/2022  By Total  NaN    NaN  United States
# 4  10/02/2022  01/01/2020  10/01/2022  By Total  NaN    NaN  United States
# 5  10/02/2022  01/01/2020  10/01/2022  By Total  NaN    NaN  United States
# 6  10/02/2022  01/01/2020  10/01/2022  By Total  NaN    NaN  United States
# 7  10/02/2022  01/01/2020  10/01/2022  By Total  NaN    NaN  United States
# 8  10/02/2022  01/01/2020  10/01/2022  By Total  NaN    NaN  United States
# 9  10/02/2022  01/01/2020  10/01/2022  By Total  NaN    NaN  United States
#
#         Condition Group                Condition ICD10_codes   Age Group  \
# 0  Respiratory diseases  Influenza and pneumonia     J09-J18        0-24
# 1  Respiratory diseases  Influenza and pneumonia     J09-J18       25-34
# 2  Respiratory diseases  Influenza and pneumonia     J09-J18       35-44
# 3  Respiratory diseases  Influenza and pneumonia     J09-J18       45-54
# 4  Respiratory diseases  Influenza and pneumonia     J09-J18       55-64
# 5  Respiratory diseases  Influenza and pneumonia     J09-J18       65-74
# 6  Respiratory diseases  Influenza and pneumonia     J09-J18       75-84
# 7  Respiratory diseases  Influenza and pneumonia     J09-J18         85+
# 8  Respiratory diseases  Influenza and pneumonia     J09-J18  Not stated
# 9  Respiratory diseases  Influenza and pneumonia     J09-J18    All Ages
#
#   COVID-19 Deaths Number of Mentions Flag
# 0           1,426              1,491  NaN
# 1           5,641              5,853  NaN
# 2          14,719             15,324  NaN
# 3          36,629             38,057  NaN
# 4          80,316             83,218  NaN
# 5         123,441            127,232  NaN
# 6         129,752            132,741  NaN
# 7         110,444            112,000  NaN
# 8              10                 10  NaN
# 9         502,378            515,926  NaN

# %%
'''
    pandas.to_numeric
        errors{‘ignore’, ‘raise’, ‘coerce’}, default ‘raise’
            If ‘raise’, then invalid parsing will raise an exception.
            If ‘coerce’, then invalid parsing will be set as NaN.
            If ‘ignore’, then invalid parsing will return the input.
'''
df['COVID deaths'] = pd.to_numeric(df['COVID-19 Deaths'], errors = 'coerce')
df.groupby('State')['COVID deaths'].sum()
# Out:
# State
# Alabama                  230907.0
# Alaska                    22546.0
# Arizona                  291305.0
# Arkansas                 165784.0
# California               603491.0
# Colorado                 214691.0
# Connecticut              140866.0
# Delaware                  54040.0
# District of Columbia      43470.0
# Florida                  502967.0
# Georgia                  329890.0
# Hawaii                    28776.0
# Idaho                     94157.0
# Illinois                 331257.0
# Indiana                  287469.0
# Iowa                     146941.0
# Kansas                   136662.0
# Kentucky                 252085.0
# Louisiana                209396.0
# Maine                     37296.0
# Maryland                 227450.0
# Massachusetts            211448.0
# Michigan                 305611.0
# Minnesota                211575.0
# Mississippi              205829.0
# Missouri                 236193.0
# Montana                   73639.0
# Nebraska                  97167.0
# Nevada                   175388.0
# New Hampshire             45951.0
# New Jersey               303802.0
# New Mexico               115503.0
# New York                 327622.0
# New York City            249516.0
# North Carolina           318713.0
# North Dakota              52219.0
# Ohio                     366331.0
# Oklahoma                 230497.0
# Oregon                   136934.0
# Pennsylvania             389264.0
# Puerto Rico               87615.0
# Rhode Island              64374.0
# South Carolina           248155.0
# South Dakota              65984.0
# Tennessee                300469.0
# Texas                    599862.0
# United States           1125107.0
# Utah                      92044.0
# Vermont                   14071.0
# Virginia                 228121.0
# Washington               212197.0
# West Virginia            117376.0
# Wisconsin                218455.0
# Wyoming                   32384.0
# Name: COVID deaths, dtype: float64

# %%
# The number for "United States" looks disputable. It does not look like the sum of all states. Probably it means deaths from US territories such as Puerto Rico, Guam, Virgin Island, etc.
# To avoid confusion, we exclude "United States" in subsequent analysis
df = df[df['State'].str.strip() != 'United States']
df
# Out:
#         Data As Of  Start Date    End Date     Group   Year  Month  \
# 230     10/02/2022  01/01/2020  10/01/2022  By Total    NaN    NaN
# 231     10/02/2022  01/01/2020  10/01/2022  By Total    NaN    NaN
# 232     10/02/2022  01/01/2020  10/01/2022  By Total    NaN    NaN
# 233     10/02/2022  01/01/2020  10/01/2022  By Total    NaN    NaN
# 234     10/02/2022  01/01/2020  10/01/2022  By Total    NaN    NaN
# ...            ...         ...         ...       ...    ...    ...
# 471955  10/02/2022  06/01/2022  06/30/2022  By Month  2,022    6.0
# 471956  10/02/2022  07/01/2022  07/31/2022  By Month  2,022    7.0
# 471957  10/02/2022  08/01/2022  08/31/2022  By Month  2,022    8.0
# 471958  10/02/2022  09/01/2022  09/30/2022  By Month  2,022    9.0
# 471959  10/02/2022  10/01/2022  10/01/2022  By Month  2,022   10.0
#
#               State       Condition Group                Condition  \
# 230         Alabama  Respiratory diseases  Influenza and pneumonia
# 231         Alabama  Respiratory diseases  Influenza and pneumonia
# 232         Alabama  Respiratory diseases  Influenza and pneumonia
# 233         Alabama  Respiratory diseases  Influenza and pneumonia
# 234         Alabama  Respiratory diseases  Influenza and pneumonia
# ...             ...                   ...                      ...
# 471955  Puerto Rico              COVID-19                 COVID-19
# 471956  Puerto Rico              COVID-19                 COVID-19
# 471957  Puerto Rico              COVID-19                 COVID-19
# 471958  Puerto Rico              COVID-19                 COVID-19
# 471959  Puerto Rico              COVID-19                 COVID-19
#
#        ICD10_codes Age Group COVID-19 Deaths Number of Mentions Flag  \
# 230        J09-J18      0-24              18                 18  NaN
# 231        J09-J18     25-34             100                105  NaN
# 232        J09-J18     35-44             228                235  NaN
# 233        J09-J18     45-54             537                554  NaN
# 234        J09-J18     55-64           1,159              1,194  NaN
# ...            ...       ...             ...                ...  ...
# 471955        U071  All Ages           222.0              222.0  NaN
# 471956        U071  All Ages           200.0              200.0  NaN
# 471957        U071  All Ages           222.0              222.0  NaN
# 471958        U071  All Ages           139.0              139.0  NaN
# 471959        U071  All Ages             0.0                0.0  NaN
#
#         COVID deaths
# 230             18.0
# 231            100.0
# 232            228.0
# 233            537.0
# 234              NaN
# ...              ...
# 471955         222.0
# 471956         200.0
# 471957         222.0
# 471958         139.0
# 471959           0.0
#
# [463220 rows x 15 columns]

# %%
# Part 2: Death analysis by cause and age group
df.groupby('Group')['COVID deaths'].sum()
# Out:
# Group
# By Month    5996437.0
# By Total    1528784.0
# By Year     3160534.0
# Name: COVID deaths, dtype: float64

# %%
df.groupby(['Group', 'Year', 'Month'])['COVID deaths'].sum()
# Out:
# Group     Year   Month
# By Month  2,020  1.0           0.0
#                  2.0           0.0
#                  3.0       39306.0
#                  4.0      268938.0
#                  5.0      219120.0
#                  6.0      115813.0
#                  7.0      166114.0
#                  8.0      170884.0
#                  9.0      125184.0
#                  10.0     166455.0
#                  11.0     326318.0
#                  12.0     493516.0
#           2,021  1.0      478640.0
#                  2.0      283740.0
#                  3.0      151034.0
#                  4.0      122939.0
#                  5.0      101176.0
#                  6.0       51045.0
#                  7.0       69291.0
#                  8.0      253110.0
#                  9.0      341914.0
#                  10.0     267420.0
#                  11.0     210885.0
#                  12.0     279766.0
#           2,022  1.0      474347.0
#                  2.0      330182.0
#                  3.0      111675.0
#                  4.0       38939.0
#                  5.0       48651.0
#                  6.0       62577.0
#                  7.0       88433.0
#                  8.0       91735.0
#                  9.0       47290.0
#                  10.0          0.0
# Name: COVID deaths, dtype: float64

# %%
df.groupby(['Group', 'Start Date', 'End Date'])['COVID deaths'].sum()
# Out:
# Group     Start Date  End Date
# By Month  01/01/2020  01/31/2020          0.0
#           01/01/2021  01/31/2021     478640.0
#           01/01/2022  01/31/2022     474347.0
#           02/01/2020  02/29/2020          0.0
#           02/01/2021  02/28/2021     283740.0
#           02/01/2022  02/28/2022     330182.0
#           03/01/2020  03/31/2020      39306.0
#           03/01/2021  03/31/2021     151034.0
#           03/01/2022  03/31/2022     111675.0
#           04/01/2020  04/30/2020     268938.0
#           04/01/2021  04/30/2021     122939.0
#           04/01/2022  04/30/2022      38939.0
#           05/01/2020  05/31/2020     219120.0
#           05/01/2021  05/31/2021     101176.0
#           05/01/2022  05/31/2022      48651.0
#           06/01/2020  06/30/2020     115813.0
#           06/01/2021  06/30/2021      51045.0
#           06/01/2022  06/30/2022      62577.0
#           07/01/2020  07/31/2020     166114.0
#           07/01/2021  07/31/2021      69291.0
#           07/01/2022  07/31/2022      88433.0
#           08/01/2020  08/31/2020     170884.0
#           08/01/2021  08/31/2021     253110.0
#           08/01/2022  08/31/2022      91735.0
#           09/01/2020  09/30/2020     125184.0
#           09/01/2021  09/30/2021     341914.0
#           09/01/2022  09/30/2022      47290.0
#           10/01/2020  10/31/2020     166455.0
#           10/01/2021  10/31/2021     267420.0
#           10/01/2022  10/01/2022          0.0
#           11/01/2020  11/30/2020     326318.0
#           11/01/2021  11/30/2021     210885.0
#           12/01/2020  12/31/2020     493516.0
#           12/01/2021  12/31/2021     279766.0
# By Total  01/01/2020  10/01/2022    1528784.0
# By Year   01/01/2020  12/31/2020    1054680.0
#           01/01/2021  12/31/2021    1208673.0
#           01/01/2022  10/01/2022     897181.0
# Name: COVID deaths, dtype: float64

# %%
# Looks like we need to exclude the groups "By Total" and "By Year"
df = df[~df['Group'].str.strip().isin(['By Total', 'By Year'])]

# %%
df.groupby('Condition Group')['COVID deaths'].sum()
# Out:
# Condition Group
# All other conditions and causes (residual)                                    693228.0
# Alzheimer disease                                                              51208.0
# COVID-19                                                                     1171194.0
# Circulatory diseases                                                         1254632.0
# Diabetes                                                                      264144.0
# Intentional and unintentional injury, poisoning, and other adverse events      36355.0
# Malignant neoplasms                                                           101886.0
# Obesity                                                                        82303.0
# Renal failure                                                                 205778.0
# Respiratory diseases                                                         1793711.0
# Sepsis                                                                        189017.0
# Vascular and unspecified dementia                                             152981.0
# Name: COVID deaths, dtype: float64

# %%
# Plot Condition Group vs # of Deaths
death_toll = df.groupby('Condition Group')['COVID deaths'].sum().reset_index()
death_toll.sort_values(by = 'COVID deaths', inplace = True, ascending = False)

death_toll
# Out:
#                                       Condition Group  COVID deaths
# 9                                Respiratory diseases     1793711.0
# 3                                Circulatory diseases     1254632.0
# 2                                            COVID-19     1171194.0
# 0          All other conditions and causes (residual)      693228.0
# 4                                            Diabetes      264144.0
# 8                                       Renal failure      205778.0
# 10                                             Sepsis      189017.0
# 11                  Vascular and unspecified dementia      152981.0
# 6                                 Malignant neoplasms      101886.0
# 7                                             Obesity       82303.0
# 1                                   Alzheimer disease       51208.0
# 5   Intentional and unintentional injury, poisonin...       36355.0

# %%
fig = plt.figure(figsize = (18, 5))
sns.barplot(death_toll['Condition Group'], death_toll['COVID deaths'])
plt.title('Number of Deaths by Condition Group', fontsize = 20)
plt.xlabel('Condition Group', fontsize = 15)
plt.ylabel('# Deaths', fontsize = 15)
plt.show()
# Out:
# C:\Users\ellen\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
fig = plt.figure(figsize = (18, 5))

sns.barplot(death_toll['Condition Group'], death_toll['COVID deaths'])
plt.title('Number of Deaths by Condition Group', )
